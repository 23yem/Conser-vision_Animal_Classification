# %% [markdown]
# ## Import libraries!

# %%
import pandas as pd

#pd.set_option('display.max_columns', None)  # Show all columns
#pd.set_option('display.width', 1000)        # Set console width
#pd.set_option('display.max_colwidth', 40)   # Limit the maximum width of each column

# %% [markdown]
# ## Read from trials csv

# %%
trials = pd.read_csv("trials.csv")
trials.describe()
# Out:
#           study_id     trial_id  trial_number  param_value        value
# count  1878.000000  1878.000000   1878.000000  1878.000000  1878.000000
# mean     63.660277   556.518637     98.089457   314.813014     1.632248
# std      30.402532   319.373231     68.748462   357.216384     0.084012
# min       1.000000     4.000000      0.000000     0.000101     1.512869
# 25%      44.000000   285.250000     41.000000     0.001249     1.557154
# 50%      63.000000   554.000000     88.000000    16.004976     1.601807
# 75%      77.000000   822.750000    142.750000   662.000000     1.708823
# max     106.000000  1136.000000    269.000000  1024.000000     1.906356

# %% [markdown]
# ## Divide Each Unique Study into Its Own DataFrame

# %%
# Group the DataFrame by 'study_id' and create a dictionary of DataFrames
grouped = trials.groupby('study_name')
dfs = {study_name: group for study_name, group in grouped}

# %% [markdown]
# ## Create a Sorted DataFrame for Each Study

# %%
# Sort each DataFrame by the 'value' column in descending order
sorted_dfs = {study_name: df.sort_values(by='value', ascending=True) for study_name, df in dfs.items()}

# %% [markdown]
# ## Create a DataFrame for Best Trials of Each Study

# %%
# Initialize a dictionary to hold the DataFrames of best trials for each study
best_trial_dfs = {}

for study_name, df in dfs.items():
    # Sort the trials by their order of execution (trial_number)
    df_sorted_by_trial = df.sort_values(by='trial_number')
    
    # Initialize the best value to a very small number
    best_value = -float('inf')
    
    # List to keep track of rows that were best trials at their time
    best_trials = []
    
    for _, row in df_sorted_by_trial.iterrows():
        if row['value'] > best_value:
            best_value = row['value']
            best_trials.append(row)
    
    # Create a DataFrame from the best trials
    best_trial_dfs[study_name] = pd.DataFrame(best_trials)

# %%
study_3_original_df = dfs["distributed_optimization_15"]
# study_3_sorted_df = sorted_dfs[3]
# study_3_best_trials_df = best_trial_dfs[3]

study_3_original_df.head()
# Out:
#       study_id                   study_name  trial_id  trial_number  \
# 1460       106  distributed_optimization_15       651             0
# 1461       106  distributed_optimization_15       651             0
# 1462       106  distributed_optimization_15       652             1
# 1463       106  distributed_optimization_15       652             1
# 1464       106  distributed_optimization_15       653             2
#
#      param_name  param_value     value
# 1460         lr     0.003186  1.543395
# 1461      units   205.000000  1.543395
# 1462         lr     0.009952  1.681658
# 1463      units   429.000000  1.681658
# 1464         lr     0.000235  1.579030

# %%
study_3_sorted_df = sorted_dfs["distributed_optimization_15"]

study_3_sorted_df.head(20)
# Out:
#       study_id                   study_name  trial_id  trial_number  \
# 1659       106  distributed_optimization_15       852           117
# 1658       106  distributed_optimization_15       852           117
# 1536       106  distributed_optimization_15       729            46
# 1537       106  distributed_optimization_15       729            46
# 1770       106  distributed_optimization_15       990           190
# 1771       106  distributed_optimization_15       990           190
# 1607       106  distributed_optimization_15       789            82
# 1606       106  distributed_optimization_15       789            82
# 1520       106  distributed_optimization_15       717            38
# 1521       106  distributed_optimization_15       717            38
# 1486       106  distributed_optimization_15       676            15
# 1487       106  distributed_optimization_15       676            15
# 1758       106  distributed_optimization_15       980           184
# 1759       106  distributed_optimization_15       980           184
# 1780       106  distributed_optimization_15      1005           197
# 1781       106  distributed_optimization_15      1005           197
# 1557       106  distributed_optimization_15       746            56
# 1556       106  distributed_optimization_15       746            56
# 1627       106  distributed_optimization_15       810            95
# 1626       106  distributed_optimization_15       810            95
#
#      param_name  param_value     value
# 1659      units   861.000000  1.512869
# 1658         lr     0.001817  1.512869
# 1536         lr     0.002133  1.520662
# 1537      units   290.000000  1.520662
# 1770         lr     0.001618  1.522358
# 1771      units   487.000000  1.522358
# 1607      units   557.000000  1.523193
# 1606         lr     0.001958  1.523193
# 1520         lr     0.000980  1.523387
# 1521      units   166.000000  1.523387
# 1486         lr     0.001188  1.523533
# 1487      units   887.000000  1.523533
# 1758         lr     0.001093  1.523849
# 1759      units   478.000000  1.523849
# 1780         lr     0.001458  1.525150
# 1781      units   500.000000  1.525150
# 1557      units   466.000000  1.525588
# 1556         lr     0.001180  1.525588
# 1627      units   391.000000  1.525707
# 1626         lr     0.001555  1.525707

# %%
study_3_best_trials_df = best_trial_dfs["distributed_optimization_15"]

study_3_best_trials_df.head(20)
# Out:
#       study_id                   study_name  trial_id  trial_number  \
# 1460       106  distributed_optimization_15       651             0
# 1462       106  distributed_optimization_15       652             1
# 1482       106  distributed_optimization_15       669            11
# 1518       106  distributed_optimization_15       714            37
# 1542       106  distributed_optimization_15       734            49
# 1854       106  distributed_optimization_15      1088           252
#
#      param_name  param_value     value
# 1460         lr     0.003186  1.543395
# 1462         lr     0.009952  1.681658
# 1482         lr     0.008114  1.681672
# 1518         lr     0.000126  1.689234
# 1542         lr     0.004858  1.704420
# 1854         lr     0.002077  1.727869
